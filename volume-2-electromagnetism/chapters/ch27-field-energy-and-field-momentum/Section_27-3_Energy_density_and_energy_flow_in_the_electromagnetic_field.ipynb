# %% [markdown]
# # Section 27-3: Energy density and energy flow in the electromagnetic field
#
# **Reading Notes** for Volume 2, Chapter 27, Section 3.
#
# > Insert key takeaways and equations here.
