# %% [markdown]
# # Volume 2, Chapter 1 – Electromagnetism – Reading Notes

# %% [markdown]
# ## Overview
#
# _Summarize the main ideas in your own words._

# %% [markdown]
# ## Key Definitions
#
# -
# -

# %% [markdown]
# ## Key Equations
#
# Write them with LaTeX, e.g. `$F = ma$`.

# %% [markdown]
# ## Derivations
#
# Walk through important derivations step by step.

# %% [markdown]
# ## Confusions / Questions
#
# Write anything that feels unclear here.
