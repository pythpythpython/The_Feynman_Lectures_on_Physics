# %% [markdown]
# # Section 6-2: Transforming to a rotated coordinate system
#
# **Reading Notes** for Volume 3, Chapter 6, Section 2.
#
# > Insert key takeaways and equations here.
