# %% [markdown]
# # Section 18-6: Solving Maxwell’s equations; the potentials and the wave equation
#
# **Reading Notes** for Volume 2, Chapter 18, Section 6.
#
# > Insert key takeaways and equations here.
