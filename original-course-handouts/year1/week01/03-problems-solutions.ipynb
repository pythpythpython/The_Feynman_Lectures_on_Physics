# %% [markdown]
# # Handouts – year1, week01 – Exercises (Clean Solutions)

# %% [markdown]
# Write polished, final solutions here.

# %% [markdown]
# ## Problem 1 – Solution

# %% [markdown]
# ## Problem 2 – Solution
