# %% [markdown]
# # Section 21-5: The potentials of a moving charge; the general solution of Liénard and Wiechert
#
# **Reading Notes** for Volume 2, Chapter 21, Section 5.
#
# > Insert key takeaways and equations here.
