# %% [markdown]
# # Messenger Lecture 2 – Symmetry in Physical Law – Notes

# %% [markdown]
# Use this notebook to summarize and annotate the material.
