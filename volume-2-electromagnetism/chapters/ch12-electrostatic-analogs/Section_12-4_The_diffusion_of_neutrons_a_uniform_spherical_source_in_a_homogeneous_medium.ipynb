# %% [markdown]
# # Section 12-4: The diffusion of neutrons; a uniform spherical source in a homogeneous medium
#
# **Reading Notes** for Volume 2, Chapter 12, Section 4.
#
# > Insert key takeaways and equations here.
