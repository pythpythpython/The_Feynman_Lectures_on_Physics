# %% [markdown]
# # 🗺️ Overview: Chapter 2 Master Dashboard
# ## Basic Physics
# **Goal:** Understand the transition from the classical view (particles + forces) to the modern quantum view (fields, uncertainty, particle zoo).

# %% [markdown]
# ### 📂 Reading Notes
# - [x] [Section 2-1: Introduction](./Section_2-1_Introduction.ipynb) (The Chess Game)
# - [x] [Section 2-2: Physics before 1920](./Section_2-2_Physics_before_1920.ipynb) (Electromagnetism)
# - [x] [Section 2-3: Quantum Physics](./Section_2-3_Quantum_physics.ipynb) (Uncertainty & QED)
# - [x] [Section 2-4: Nuclei and Particles](./Section_2-4_Nuclei_and_particles.ipynb) (The Particle Zoo)

# %% [markdown]
# ### 🧠 Activities & Practice
# - [ ] [🏋️ Exercise Bank](./Activity_Exercise_Bank.ipynb) (10 Deep Questions)
# - [ ] [🧠 Flashcards](./Activity_Flashcards.ipynb) (Interactive Widget)
# - [ ] [📓 AI Q&A Log](./Log_AI_QA_Journal.ipynb) (Deep Insights)

# %% [markdown]
# ### 📊 Progress Status
# mark `[x]` when complete:
# - [ ] Finished all readings
# - [ ] Completed self-test exercises
# - [ ] Reviewed flashcards
