# %% [markdown]
# # Tips on Physics – Chapter 2 – Exercises (In Progress)

# %% [markdown]
# Use this for rough work. It can be messy.

# %% [markdown]
# ## Problem 1 (rough)

# %% [markdown]
# ## Problem 2 (rough)
