# %% [markdown]
# # Feynman Notes – Electromagnetism – Crosslinks – Notes

# %% [markdown]
# Use this notebook to summarize and annotate the material.
