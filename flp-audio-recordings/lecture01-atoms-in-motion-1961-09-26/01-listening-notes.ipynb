# %% [markdown]
# # Audio Lecture 1 – Atoms in Motion (1961-09-26) – Notes

# %% [markdown]
# Use this notebook to summarize and annotate the material.
