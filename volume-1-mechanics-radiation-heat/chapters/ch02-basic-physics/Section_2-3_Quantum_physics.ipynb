# %% [markdown]
# # 📚 Feynman Lectures, Vol 1 — Chapter 2: Basic Physics
# ## Section 2-3: Quantum Physics
#
# This section is a high-level introduction to the revolution in physics that occurred around 1925, leading to the creation of quantum mechanics and the modern view of the atom, space-time, and the fundamental unpredictability of nature.

# %% [markdown]
# ### 🌀 The Quantum Leap
# - **Space/time changed:** After 1920, Einstein unified space & time (special relativity), then curved space-time for gravity (general relativity).
# - **Newton’s laws fail at small scales:** On the atomic scale, ideas like position, speed, and force are replaced with quantum laws that defy our everyday intuition.
# - **Key point:** Small-scale physics is “unnatural”—there’s nothing in daily experience like it, and it’s best described mathematically, not pictorially.

# %% [markdown]
# ### 🔏 The Uncertainty Principle & Atomic Stability
# - **No definite position *and* speed:** The quantum rule: $\Delta x \Delta p \geq \hbar/2$
# - **Why atoms don’t collapse:** If electrons could sit right on the nucleus, their position would be certain—their momentum, wildly uncertain and correspondingly huge, would launch them away. They “compromise” by clouding around the nucleus.
# - Even at absolute zero, all matter still “jitters” because you can’t know position and velocity exactly at once!

# %% [markdown]
# ### 🎲 Predictability in Science: Gone!
# - **Fundamental randomness:** Even given a complete description, quantum mechanics says you cannot predict exactly what will happen—only probabilities/statistics.
# - Repetition of experiments does *not* guarantee the same outcome—real randomness, not just ignorance.
# - Scientists make laws by summarizing experimental experience—nature, not philosophy, is the judge.

# %% [markdown]
# ### 🌊 Particles, Waves, and Unification
# - **Wave–particle duality:** Everything behaves both as a particle and as a wave—no distinction in the ultimate theory.
# - Low-frequency EM phenomena (light, radio) behave “wavelike”; high-frequency (X-rays, gamma) behave “particulate.”

# %% [markdown]
# ### ✨ Quantum Electrodynamics (QED)
# - **Core idea:** A new quantum particle, the photon, mediates electromagnetic force (joining the electron, proton, neutron).
# - QED is the most tested and precise theory in science. It underlies virtually all of chemistry and most of physics except for nuclear forces and gravitation.

# %% [markdown]
# ### ⏩ Consequences & Antimatter
# - **QED predicted positrons (antiparticles with opposite charge):** Electron + positron can annihilate to light (photon/gamma ray).
# - Rule: For every particle, there’s an antiparticle (antiproton, antineutron, etc.).
# - Chemistry, biology, all build on these quantum rules—and every new test has matched quantum predictions so far.

# %% [markdown]
# ### 💡 Reflection
# - “We can only find an *average* for what happens, not precise prediction.”
# - The fact that atoms are *big* and don’t collapse follows directly from the uncertainty principle.
