# %% [markdown]
# # 🗺️ Overview: Chapter 4 Master Dashboard
# ## Conservation of Energy
# **Big Idea:** Energy is a number that never changes, though it transforms between many forms.

# %% [markdown]
# ### 📂 Reading Notes
# - [x] [Section 4-1: What is energy?](./Section_4-1_What_is_energy.ipynb) (Dennis the Menace)
# - [x] [Section 4-2: Gravitational Potential Energy](./Section_4-2_Gravitational_potential_energy.ipynb) (Reversible Machines)
# - [x] [Section 4-3: Kinetic Energy](./Section_4-3_Kinetic_energy.ipynb) (The Pendulum)
# - [x] [Section 4-4: Other Forms of Energy](./Section_4-4_Other_forms_of_energy.ipynb) (Elastic, Heat, Nuclear, Mass)

# %% [markdown]
# ### 🧠 Activities & Practice
# - [ ] [🔍 Energy Detective](./Activity_Energy_Detective.ipynb)
# - [ ] [🧪 Conservation Lab](./Activity_Conservation_Lab.ipynb)
# - [ ] [🧠 Energy Quiz](./Activity_Energy_Quiz.ipynb)

# %% [markdown]
# ### 📊 Progress Status
# Mark `[x]` when complete:
# - [ ] Traced energy in all 4 detective scenarios
# - [ ] Ran the pendulum simulation
# - [ ] Passed the quiz (Score > 6/8)

# %% [markdown]
# ### 🎯 Key Takeaways
# - Energy is not a "thing"—it's a calculated number.
# - PE = mgh (gravitational)
# - KE = ½mv²
# - Energy transforms but never disappears (in a closed system).
