# %% [markdown]
# # Section 13-5: The magnetic field of a straight wire and of a solenoid; atomic currents
#
# **Reading Notes** for Volume 2, Chapter 13, Section 5.
#
# > Insert key takeaways and equations here.
