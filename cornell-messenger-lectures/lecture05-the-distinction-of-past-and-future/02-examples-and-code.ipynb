# %% [markdown]
# # Messenger Lecture 5 – The Distinction of Past and Future – Examples and Code Experiments

# %% [markdown]
# Use this notebook for extra examples, numerical checks, and visualizations.

# %%
# import common tools
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
