# %% [markdown]
# # Section 9-1: The electric potential gradient of the atmosphere
#
# **Reading Notes** for Volume 2, Chapter 9, Section 1.
#
# > Insert key takeaways and equations here.
