# %% [markdown]
# # Section 21-6: The potentials for a charge moving with constant velocity; the Lorentz formula
#
# **Reading Notes** for Volume 2, Chapter 21, Section 6.
#
# > Insert key takeaways and equations here.
