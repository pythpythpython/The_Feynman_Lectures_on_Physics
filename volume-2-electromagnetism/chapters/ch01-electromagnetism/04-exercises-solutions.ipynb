# %% [markdown]
# # Volume 2, Chapter 1 – Electromagnetism – Exercises (Clean Solutions)

# %% [markdown]
# Write polished, final solutions here.

# %% [markdown]
# ## Problem 1 – Solution

# %% [markdown]
# ## Problem 2 – Solution
