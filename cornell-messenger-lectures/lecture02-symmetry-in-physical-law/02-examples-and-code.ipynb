# %% [markdown]
# # Messenger Lecture 2 – Symmetry in Physical Law – Examples and Code Experiments

# %% [markdown]
# Use this notebook for extra examples, numerical checks, and visualizations.

# %%
# import common tools
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
