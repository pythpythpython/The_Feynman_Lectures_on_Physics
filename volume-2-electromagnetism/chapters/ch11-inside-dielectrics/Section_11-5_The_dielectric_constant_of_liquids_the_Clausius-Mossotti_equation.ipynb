# %% [markdown]
# # Section 11-5: The dielectric constant of liquids; the Clausius-Mossotti equation
#
# **Reading Notes** for Volume 2, Chapter 11, Section 5.
#
# > Insert key takeaways and equations here.
