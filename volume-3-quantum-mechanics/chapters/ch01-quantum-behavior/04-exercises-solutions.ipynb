# %% [markdown]
# # Volume 3, Chapter 1 – Quantum Behavior – Exercises (Clean Solutions)

# %% [markdown]
# Write polished, final solutions here.

# %% [markdown]
# ## Problem 1 – Solution

# %% [markdown]
# ## Problem 2 – Solution
