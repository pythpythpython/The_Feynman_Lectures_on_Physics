# %% [markdown]
# # Messenger Lecture 4 – The Quantum Mechanical View of Nature – Examples and Code Experiments

# %% [markdown]
# Use this notebook for extra examples, numerical checks, and visualizations.

# %%
# import common tools
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
