# %% [markdown]
# # 🗺️ Chapter 1 Master Overview: Atoms in Motion
# ## The Command Center

# %% [markdown]
# ## 📖 1. Reading Notes (The Theory)
# The core text broken down by section:
#
# - **[Section 1-1: Introduction](Section_1-1_Introduction.ipynb)**
# - **[Section 1-2: Matter is Made of Atoms](Section_1-2_Matter_is_Made_of_Atoms.ipynb)**
# - **[Section 1-3: Atomic Processes](Section_1-3_Atomic_Processes.ipynb)**
# - **[Section 1-4: Chemical Reactions](Section_1-4_Chemical_Reactions.ipynb)**

# %% [markdown]
# ## 🔬 2. The Laboratory (Activities)
# Interactive tools to deepen your understanding:
#
# - **[Interactive Playground](Activity_Interactive_Playground.ipynb)** (Simulations)
# - **[Exercise Bank](Activity_Exercise_Bank.ipynb)** (Problems & Solutions)
# - **[Flashcards](Activity_Flashcards.ipynb)** (Active Recall Deck)

# %% [markdown]
# ## 📓 3. Your Journal
# - **[AI Q&A Log](Log_AI_QA_Journal.ipynb)**
