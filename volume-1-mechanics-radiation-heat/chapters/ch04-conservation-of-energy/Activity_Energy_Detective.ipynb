# %% [markdown]
# # 🔍 Activity: Energy Detective
# ## Trace Energy Transformations
# In this activity, you will track energy as it transforms from one form to another in real-world scenarios.

# %% [markdown]
# ### Scenario 1: A Roller Coaster
# A roller coaster car starts at the top of a 50-meter hill and rolls down (ignore friction).
#
# **Question:** Trace the energy transformations from start to bottom.
#
# **Steps:**
# 1. At the top: What type of energy does it have?
# 2. Halfway down: What types of energy are present?
# 3. At the bottom: What type of energy dominates?
#
# > [Your answer here...]

# %% [markdown]
# ### Scenario 2: A Bouncing Ball
# You drop a rubber ball from a height of 2 meters.
#
# **Question:** Track the energy as it bounces.
#
# 1. Before release: PE = ?
# 2. Just before hitting ground: KE = ?
# 3. At the moment of maximum compression: What type of energy?
# 4. After the bounce, does it return to 2 meters? Why or why not?
#
# > [Your answer here...]

# %% [markdown]
# ### Scenario 3: A Hydroelectric Dam
# Water at the top of a dam falls through turbines to generate electricity.
#
# **Question:** Map the energy chain.
#
# PE (water at top) → ? → ? → Electrical Energy
#
# > [Your answer here...]

# %% [markdown]
# ### Scenario 4: You!
# You eat a sandwich and then climb stairs.
#
# **Question:** Trace the energy from food to gravitational potential energy.
#
# Chemical Energy (sandwich) → ? → ? → PE (you at top of stairs)
#
# > [Your answer here...]
