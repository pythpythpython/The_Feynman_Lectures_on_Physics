# %% [markdown]
# # Section 30-1: The resultant amplitude due to n equal oscillators
#
# **Reading Notes** for Chapter 30, Section 1.
#
# > Insert key takeaways and equations here.
