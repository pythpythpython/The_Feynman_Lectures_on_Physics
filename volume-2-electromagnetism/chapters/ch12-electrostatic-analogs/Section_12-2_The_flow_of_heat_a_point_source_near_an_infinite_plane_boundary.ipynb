# %% [markdown]
# # Section 12-2: The flow of heat; a point source near an infinite plane boundary
#
# **Reading Notes** for Volume 2, Chapter 12, Section 2.
#
# > Insert key takeaways and equations here.
