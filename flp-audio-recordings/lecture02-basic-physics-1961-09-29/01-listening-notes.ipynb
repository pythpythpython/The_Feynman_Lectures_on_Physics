# %% [markdown]
# # Audio Lecture 2 – Basic Physics (1961-09-29) – Notes

# %% [markdown]
# Use this notebook to summarize and annotate the material.
