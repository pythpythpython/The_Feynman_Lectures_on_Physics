# %% [markdown]
# # Section 5-1: Filtering atoms with a Stern-Gerlach apparatus
#
# **Reading Notes** for Volume 3, Chapter 5, Section 1.
#
# > Insert key takeaways and equations here.
