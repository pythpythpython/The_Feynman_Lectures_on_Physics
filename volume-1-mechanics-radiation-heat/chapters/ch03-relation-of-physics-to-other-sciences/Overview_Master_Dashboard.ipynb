# %% [markdown]
# # 🗺️ Overview: Chapter 3 Master Dashboard
# ## The Relation of Physics to Other Sciences
# **Goal:** Understand how Physics serves as the foundation for Chemistry, Biology, Astronomy, and Geology.

# %% [markdown]
# ### 📂 Reading Notes
# - [x] [Section 3-1: Introduction](./Section_3-1_Introduction.ipynb) (Natural Philosophy)
# - [x] [Section 3-2: Chemistry](./Section_3-2_Chemistry.ipynb) (Quantum Mechanics)
# - [x] [Section 3-3: Biology](./Section_3-3_Biology.ipynb) (DNA & Enzymes)
# - [x] [Section 3-4: Astronomy](./Section_3-4_Astronomy.ipynb) (Spectroscopy & Fusion)
# - [x] [Section 3-5: Geology](./Section_3-5_Geology.ipynb) (Turbulence & Core Paradox)
# - [x] [Section 3-6: Psychology](./Section_3-6_Psychology.ipynb) (Memory & Brains)
# - [x] [Section 3-7: How did it get that way?](./Section_3-7_How_did_it_get_that_way.ipynb) (The Glass of Wine)

# %% [markdown]
# ### 🧠 Activities & Practice
# - [ ] [🗺️ Deep Connections Map](./Activity_Deep_Connections_Map.ipynb)
# - [ ] [🧪 Interdisciplinary Quiz](./Activity_Interdisciplinary_Quiz.ipynb)
# - [ ] [📓 AI Q&A Log](./Log_AI_QA_Journal.ipynb)

# %% [markdown]
# ### 📊 Progress Status
# mark `[x]` when complete:
# - [ ] Filled out the Connections Map
# - [ ] Passed the Quiz (Score > 6/8)
# - [ ] Reflected on the "Glass of Wine"
