# %% [markdown]
# # Handouts – year2, week01 – Exercises (In Progress)

# %% [markdown]
# Use this for rough work. It can be messy.

# %% [markdown]
# ## Problem 1 (rough)

# %% [markdown]
# ## Problem 2 (rough)
