# %% [markdown]
# # Messenger Lecture 6 – Probability and Uncertainty – Notes

# %% [markdown]
# Use this notebook to summarize and annotate the material.
