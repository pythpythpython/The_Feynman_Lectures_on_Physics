# %% [markdown]
# # Section 34-6: Classical physics gives neither diamagnetism nor paramagnetism
#
# **Reading Notes** for Volume 2, Chapter 34, Section 6.
#
# > Insert key takeaways and equations here.
