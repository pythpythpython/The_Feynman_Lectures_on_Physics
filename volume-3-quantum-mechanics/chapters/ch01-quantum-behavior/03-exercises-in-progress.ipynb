# %% [markdown]
# # Volume 3, Chapter 1 – Quantum Behavior – Exercises (In Progress)

# %% [markdown]
# Use this for rough work. It can be messy.

# %% [markdown]
# ## Problem 1 (rough)

# %% [markdown]
# ## Problem 2 (rough)
