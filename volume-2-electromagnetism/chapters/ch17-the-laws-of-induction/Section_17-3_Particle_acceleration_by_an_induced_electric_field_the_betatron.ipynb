# %% [markdown]
# # Section 17-3: Particle acceleration by an induced electric field; the betatron
#
# **Reading Notes** for Volume 2, Chapter 17, Section 3.
#
# > Insert key takeaways and equations here.
