# %% [markdown]
# # Section 15-1: The forces on a current loop; energy of a dipole
#
# **Reading Notes** for Volume 2, Chapter 15, Section 1.
#
# > Insert key takeaways and equations here.
