# %% [markdown]
# # Messenger Lecture 1 – The Law of Gravitation – Notes

# %% [markdown]
# Use this notebook to summarize and annotate the material.
