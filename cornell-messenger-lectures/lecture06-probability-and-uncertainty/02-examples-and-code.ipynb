# %% [markdown]
# # Messenger Lecture 6 – Probability and Uncertainty – Examples and Code Experiments

# %% [markdown]
# Use this notebook for extra examples, numerical checks, and visualizations.

# %%
# import common tools
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
